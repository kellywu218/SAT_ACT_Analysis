# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement
#
# With the continuously advancing society we live in, the minimum requirements and qualifications for job positions is increasing. In addition to relevant field experience, many positions are beginning to add in a college education as a minimum; some are even adding in a continued education as a minimum. So when looking at higher education institutions, we notice that there is an application requirement known as the SAT or ACT, which are exams that measure a person's readiness for college.
#
# The learning curve is different for everyone, no matter what. We have those who grasp new concepts and material immediately, those who remain bewildered despite countless hours of studying, and those who fall somewhere in between the two. Almost all of the states in the U.S. have adopted what are known as the common core standards - the basics of what you should know and takeaway from English, Math, History, and Science during each grade - that way the national curriculum and performance should be relatively the same. With this logic, academic performance should be generally equal across states and individuals, right?
#
# Unfortunately, it isn't. With data collected from College Board and ACT, Inc., we will try to identify any major factors that may have contributed to performances on the SAT and ACT in 2017 and 2018. Ultimately, conclude a general statement that can explain what we notice and create recommendations on how to close any found gaps.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# We took the individual datasets and began with cleaning it up to ensure that all the data was accurate and efficient to work with when comparing different variables such as participation rates and overall exam scores. Upon arriving at a polished data set, we were able to view statistics of each state in the U.S. (including the District of Columbia) regarding participation, overall scores, and test section scores.
#
# Through exploratory analysis, the data yielded nothing significant that required immediate attention. Participation was notable as the SAT participation rates in 2017 and 2018 were significantly lower than the ACT participation rates in 2017 and 2018 - more than double. This does pose interest given the following differences between the two exams:
#
# - SAT is a longer exam (by about 10 minutes when opting for the essay)
# - ACT has more questions (61 more questions than the SAT)
# - ACT costs more ($3 more than the SAT or 2.50 more when opting for the essay)
#
# Given these three factors, the SAT would seem more appealing than the SAT, but the ACT had significiantly higher national participation rates than the SAT. Based on this line of interest, we delved into correlations between years and other variables like overall score. For 2017, SAT participation and SAT total scores have almost a perfect negative correlation meaning that a state with a higher participation rate had a lower total score. However, for 2018, the correlation between the two are almost perfectly positive meaning that a state with a higher participation rate had a higher total score. On the other hand, when we looked at the correlation between participation and composite score for the ACT, both years yielded near perfect negative correlations.
#
# Given some interesting relationships, we dived deeper into looking at signficant states. In this case, Maine, Minnesota, and the District of Columbia were analyzed.
#
# - District of Columbia has one of the highest SAT participation rates, but has the lowest total score in both 2017 and 2018.
#
# - Minnesota has one of the lowest SAT participation rates, but has the highest total score in both 2017 and 2018.
#
# - Maine has the lowest ACT participation rates and the highest ACT Composite Scores in both 2017 and 2018 - well above the national average.

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
sat_data_17 = pd.read_csv('../data/sat_2017.csv')
act_data_17 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
sat_data_17.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_data_17.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: The SAT data gives a simple breakdown of each state's (including the District of Columbia) SAT exam participation followed by the state's average Reading and Writing score, average Math score, and the total of those two averages, which gives the average SAT score.
#
# The ACT data gives a simple breakdown of each state's (including the District of Columbia) ACT exam participation followed by the state's average English, Math, Reading, Science, and the average of the four section averages as the Composite. In addition, the ACT data includes a breakdown for the National level.

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
print(sat_data_17['State'].isnull().sum())
print(act_data_17['State'].isnull().sum())
# Out:
# 0
# 0

# %%
print(sat_data_17['Participation'].isnull().sum())
print(act_data_17['Participation'].isnull().sum())
# Out:
# 0
# 0

# %%
print(sat_data_17['Evidence-Based Reading and Writing'].isnull().sum())
print(sat_data_17['Math'].isnull().sum())
print(sat_data_17['Total'].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
print(act_data_17['English'].isnull().sum())
print(act_data_17['Math'].isnull().sum())
print(act_data_17['Reading'].isnull().sum())
print(act_data_17['Science'].isnull().sum())
print(act_data_17['Composite'].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# Answer: Yes, the data seems to be complete as there are 51 filled entries for each column in the SAT data (2017) given the 50 states and District of Columbia; the same for ACT data (2017) given the 50 states, District of Columbia, and National.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat_data_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_data_17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# Answer: There is a discrepancy with the SAT Math section's minimum score. According to the College Board, the lowest score possible on any individual section is 200, but there is a reported score of 52.
#
# The ACT dataset doesn't show any immediate discrepancies as each section is graded on a scale of 1 to 36. So, even though the Science section has a significantly lower minimum value, it still falls within the range of the possible scores.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
sat_data_17.sort_values(by = 'Math', ascending = True).head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %% [markdown]
# This was to adjust Maryland's Math score from 52 to 524.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_data_17.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_data_17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: I learned the type of each columns' values, but Participation is classified as an object even though the are numerical values (percentages). In addition, the Composite column for the ACT dataset is an object when it should be comprised of floats so this means that there may be a different datatype within the column such as a string.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
sat_participation = sat_data_17['Participation'].apply(lambda row: row.strip('%'))
# Source: https://stackoverflow.com/questions/12432663/what-is-a-clean-way-to-convert-a-string-percent-to-a-float
# Source: https://stackoverflow.com/questions/45488968/how-to-remove-a-value-from-a-list-in-a-pandas-dataframe

# %%
def to_num(sat_participation):
    try:
        out = float(sat_participation)
    except:
        out = np.nan
    return out

# %%
sat_data_17['Participation'] = sat_participation.apply(to_num)

# %% [markdown]
# This was to convert the SAT Participation values from a string type to a float type despite there being a numeric visual.

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act_data_17.loc[51, 'Composite'] = 20.2
# To adjust Wyoming's Composite from 20.2x to 20.2

act_data_17.loc[21, 'Science'] = 23.2
# To change Maryland's Science score from 2.3 to 23.2

sat_data_17.loc[20, 'Math'] = 524
# To change Maryland's Math from 52 to 524

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
act_participation = act_data_17['Participation'].apply(lambda row: row.strip('%'))

def to_num(act_participation):
    try:
        out = float(act_participation)
    except:
        out = np.nan
    return out

act_data_17['Participation'] = act_participation.apply(to_num)

# %%
act_data_17['Composite'] = act_data_17['Composite'].apply(float)

# %% [markdown]
# This was to convert the ACT Participation values from a string type to a float type despite there being a numeric visual.

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
act_data_17.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat_data_17.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_data_17.columns = ['state',
                       'sat_participation',
                       'sat_reading_and_writing',
                       'sat_math',
                       'sat_total']

# %%
act_data_17.columns = ['state',
                       'act_participation',
                       'act_english',
                       'act_math',
                       'act_reading',
                       'act_science',
                       'act_composite']

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|Object|2017 ACT/2017 SAT|50 States of the US and District of Columbia|
# |Participation|Float|2017 ACT/2017 SAT|The participation rate of each state for the ACT/SAT|
# |SAT Reading and Writing|Integer|2017 SAT|Each state's average reading and writing score (On a scale of 200 to 800)|
# |SAT Math|Integer|2017 SAT|Each state's average math score (On a scale of 200 to 800)|
# |SAT Total|Integer|2017 SAT|Each state's total score of the average reading and writing and math (On a scale of 400 to 1600)|
# |ACT English|Float|2017 ACT|Each state's average english score (On a scale of 1 to 36)|
# |ACT Math|Float|2017 ACT|Each state's average math score (On a scale of 1 to 36)|
# |ACT Reading|Float|2017 ACT|Each state's average reading score (On a scale of 1 to 36)|
# |ACT Science|Float|2017 ACT|Each state's average science score (On a scale of 1 to 36)|
# |ACT Total|Float|2017 ACT|Each state's average total score of all four sections (On a scale of 1 to 36)|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act_data_17 = act_data_17.drop(0)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_17 = sat_data_17.merge(act_data_17, on = 'state')

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combined_17.to_csv('../data/combined_2017.csv', index = False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# #### 1. Read In SAT & ACT  Data and Display Data
#
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes.
#
# Display the first 5 values of each data set.

# %%
sat_data_18 = pd.read_csv('../data/sat_2018.csv')
act_data_18 = pd.read_csv('../data/act_2018.csv')

# %%
sat_data_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
act_data_18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %% [markdown]
# #### 2. View the Summary Statistics and Fix Any Errors
#
# Are the datasets complete or do they have missing values? Are there any obvious discrepancies from "previewing" the data?

# %%
act_data_18.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
sat_data_18.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
print(sat_data_18['State'].isnull().sum())
print(sat_data_18['Participation'].isnull().sum())
print(sat_data_18['Evidence-Based Reading and Writing'].isnull().sum())
print(sat_data_18['Math'].isnull().sum())
print(sat_data_18['Total'].isnull().sum())
print(act_data_18['State'].isnull().sum())
print(act_data_18['Participation'].isnull().sum())
print(act_data_18['State'].isnull().sum())
print(act_data_18['Composite'].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# Maine was entered twice so this is to delete one of them
act_data_18.drop(20, inplace = True)

# %%
# Shows me if all the states were typed in correctly
set(act_data_18['State']) - set(sat_data_18['State'])
# Out:
# {'District of columbia'}

# %%
act_data_18.loc[8, 'State'] = 'District of Columbia'

# %% [markdown]
# ---
# - Adjust the SAT/ACT Participation types from object to float.
# ---

# %%
act_part = act_data_18['Participation'].apply(lambda row: row.strip('%'))

def to_num(act_part):
    try:
        out = float(act_part)
    except:
        out = np.nan
    return out

act_data_18['Participation'] = act_part.apply(to_num)

# %%
sat_part = sat_data_18['Participation'].apply(lambda row: row.strip('%'))

def to_num(sat_part):
    try:
        out = float(sat_part)
    except:
        out = np.nan
    return out

sat_data_18['Participation'] = sat_part.apply(to_num)

# %% [markdown]
# ---
# - Final review to ensure that any obvious discrepancies or errors have been fixed.
# ---

# %%
act_data_18.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
sat_data_18.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_data_18.describe()
# Out:
#        Participation  Composite
# count      51.000000  51.000000
# mean       61.725490  21.496078
# std        34.037085   2.111583
# min         7.000000  17.700000
# 25%        28.500000  19.950000
# 50%        66.000000  21.300000
# 75%       100.000000  23.650000
# max       100.000000  25.600000

# %%
sat_data_18.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean       45.745098                          563.686275  556.235294
# std        37.314256                           47.502627   47.772623
# min         2.000000                          480.000000  480.000000
# 25%         4.500000                          534.500000  522.500000
# 50%        52.000000                          552.000000  544.000000
# 75%        77.500000                          610.500000  593.500000
# max       100.000000                          643.000000  655.000000
#
#              Total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %% [markdown]
# ---
# - Rename columns to lowercase for easier referencing and indexing.
# ---

# %%
sat_data_18.columns = ['state',
                       'sat_participation_18',
                       'sat_reading_and_writing_18',
                       'sat_math_18',
                       'sat_total_18']

# %%
act_data_18.columns = ['state', 
                       'act_participation_18',
                       'act_composite_18']

# %% [markdown]
# ---
# - Merge the 2018 SAT and ACT DataFrames into "combined_18" based on the 50 states and the District of Columbia.
# ---

# %%
combined_18 = sat_data_18.merge(act_data_18, on = 'state')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# To differentiate the 2017 averages from the 2018 averages
combined_17.columns = ['state',
                    'sat_participation_17',
                    'sat_reading_and_writing_17',
                    'sat_math_17',
                    'sat_total_17',
                    'act_participation_17',
                    'act_english_17',
                    'act_math_17',
                    'act_reading_17',
                    'act_science_17',
                    'act_composite_17']

# %% [markdown]
# ---
# - Preview that all columns of both combined DataFrames are classified properly and clearly before final merge.
# ---

# %%
combined_17.head()
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 0     Alabama                   5.0                         593          572
# 1      Alaska                  38.0                         547          533
# 2     Arizona                  30.0                         563          553
# 3    Arkansas                   3.0                         614          594
# 4  California                  53.0                         531          524
#
#    sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 0          1165                 100.0            18.9         18.4
# 1          1080                  65.0            18.7         19.8
# 2          1116                  62.0            18.6         19.8
# 3          1208                 100.0            18.9         19.0
# 4          1055                  31.0            22.5         22.7
#
#    act_reading_17  act_science_17  act_composite_17
# ...

# %%
combined_18.head()
# Out:
#         state  sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 0     Alabama                   6.0                         595          571
# 1      Alaska                  43.0                         562          544
# 2     Arizona                  29.0                         577          572
# 3    Arkansas                   5.0                         592          576
# 4  California                  60.0                         540          536
#
#    sat_total_18  act_participation_18  act_composite_18
# 0          1166                 100.0              19.1
# 1          1106                  33.0              20.8
# 2          1149                  66.0              19.2
# 3          1169                 100.0              19.4
# 4          1076                  27.0              22.7

# %% [markdown]
# ---
# - Combining the 2017 ACT/SAT and 2018 ACT/SAT data into one single DataFrame.
# ---

# %%
final = combined_17.merge(combined_18, on = 'state')

# %%
final.head()
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 0     Alabama                   5.0                         593          572
# 1      Alaska                  38.0                         547          533
# 2     Arizona                  30.0                         563          553
# 3    Arkansas                   3.0                         614          594
# 4  California                  53.0                         531          524
#
#    sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 0          1165                 100.0            18.9         18.4
# 1          1080                  65.0            18.7         19.8
# 2          1116                  62.0            18.6         19.8
# 3          1208                 100.0            18.9         19.0
# 4          1055                  31.0            22.5         22.7
#
#    act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().T
# Out:
#                             count         mean        std    min      25%  \
# sat_participation_17         51.0    39.803922  35.276632    2.0     4.00
# sat_reading_and_writing_17   51.0   569.117647  45.666901  482.0   533.50
# sat_math_17                  51.0   556.882353  47.121395  468.0   523.50
# sat_total_17                 51.0  1126.098039  92.494812  950.0  1055.50
# act_participation_17         51.0    65.254902  32.140842    8.0    31.00
# act_english_17               51.0    20.931373   2.353677   16.3    19.00
# act_math_17                  51.0    21.182353   1.981989   18.0    19.40
# act_reading_17               51.0    22.013725   2.067271   18.1    20.45
# act_science_17               51.0    21.450980   1.739353   18.2    19.95
# act_composite_17             51.0    21.519608   2.020695   17.8    19.80
# sat_participation_18         51.0    45.745098  37.314256    2.0     4.50
# sat_reading_and_writing_18   51.0   563.686275  47.502627  480.0   534.50
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# Vlad Bezden
# https://stackoverflow.com/questions/24023927/computing-standard-deviation-without-packages-in-python

def standard_deviation(value): 
    mean = sum(value) / len(value)
    variance = sum((i - mean)**2 for i in value)
    std_dev = (variance/ len(value)) ** 0.5
    return std_dev

standard_deviation(final['act_composite_18'])
# Out:
# 2.090779082141178

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final.dtypes
# Out:
# state                          object
# sat_participation_17          float64
# sat_reading_and_writing_17      int64
# sat_math_17                     int64
# sat_total_17                    int64
# act_participation_17          float64
# act_english_17                float64
# act_math_17                   float64
# act_reading_17                float64
# act_science_17                float64
# act_composite_17              float64
# sat_participation_18          float64
# sat_reading_and_writing_18      int64
# sat_math_18                     int64
# sat_total_18                    int64
# act_participation_18          float64
# act_composite_18              float64
# dtype: object

# %%
final_dict = {col.name :standard_deviation(col) for col in [final[i] for i in final.columns if (final[i].dtype =='float64') or (final[i].dtype == 'int64')]}

# %%
final_dict
# Out:
# {'sat_participation_17': 34.92907076664508,
#  'sat_reading_and_writing_17': 45.21697020437866,
#  'sat_math_17': 46.65713364485503,
#  'sat_total_17': 91.58351056778743,
#  'act_participation_17': 31.824175751231806,
#  'act_english_17': 2.3304876369363363,
#  'act_math_17': 1.9624620273436781,
#  'act_reading_17': 2.0469029314842646,
#  'act_science_17': 1.7222161451443676,
#  'act_composite_17': 2.000786081581989,
#  'sat_participation_18': 36.946619223539415,
#  'sat_reading_and_writing_18': 47.03460978357609,
#  'sat_math_18': 47.30194550378352,
#  'sat_total_18': 93.22742384464433,
#  'act_participation_18': 33.70173582041031,
#  'act_composite_18': 2.090779082141178}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
np.std(final['act_composite_18'])
# Out:
# 2.090779082141178

# %% [markdown]
# Answer: My manually calculated standard deviations do not match up with the output from pandas `describe`, but my manually calculated standard deviations do match up to numpy's `std` method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# - Below are the lines of code for sorting the combined data by specific participation rates.

# %%
final.sort_values(by = 'sat_participation_17', ascending = True).head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 34  North Dakota                   2.0                         635
# 24   Mississippi                   2.0                         634
# 15          Iowa                   2.0                         641
# 25      Missouri                   3.0                         640
# 44          Utah                   3.0                         624
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 34          621          1256                  98.0            19.0
# 24          607          1242                 100.0            18.2
# 15          635          1275                  67.0            21.2
# 25          631          1271                 100.0            19.8
# 44          614          1238                 100.0            19.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 34         20.4            20.5            20.6              20.3
# ...

# %%
final.sort_values(by = 'sat_participation_17', ascending = False).head()
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 8   District of Columbia                 100.0                         482
# 22              Michigan                 100.0                         509
# 6            Connecticut                 100.0                         530
# 7               Delaware                 100.0                         503
# 29         New Hampshire                  96.0                         532
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8           468           950                  32.0            24.4
# 22          495          1005                  29.0            24.1
# 6           512          1041                  31.0            25.5
# 7           492           996                  18.0            24.1
# 29          520          1052                  18.0            25.4
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# ...

# %%
final.sort_values(by = 'act_participation_17', ascending = True).head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 19          Maine                  95.0                         513
# 29  New Hampshire                  96.0                         532
# 7        Delaware                 100.0                         503
# 39   Rhode Island                  71.0                         539
# 38   Pennsylvania                  65.0                         540
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 19          499          1012                   8.0            24.2
# 29          520          1052                  18.0            25.4
# 7           492           996                  18.0            24.1
# 39          524          1062                  21.0            24.0
# 38          531          1071                  23.0            23.4
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 19         24.0            24.8            23.7              24.3
# ...

# %%
high_act_part_17 = final['act_participation_17'] == 100.0
final[high_act_part_17]
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 0          Alabama                   5.0                         593
# 3         Arkansas                   3.0                         614
# 5         Colorado                  11.0                         606
# 17        Kentucky                   4.0                         631
# 18       Louisiana                   4.0                         611
# 23       Minnesota                   3.0                         644
# 24     Mississippi                   2.0                         634
# 25        Missouri                   3.0                         640
# 26         Montana                  10.0                         605
# 28          Nevada                  26.0                         563
# 33  North Carolina                  49.0                         546
# 36        Oklahoma                   7.0                         530
# 40  South Carolina                  50.0                         543
# ...

# %% [markdown]
# ---
# ### Here we have the states with the highest and lowest participation rates for the SAT and ACT in 2017:
#
# |State|SAT Participation Rate|
# |---|---|
# |District of Columbia|100%|
# |Michigan|100%|
# |Connecticut|100%|
# |Delaware|100%|
# |...|...|
# |North Dakota|2%|
# |Mississippi|2%|
# |Iowa|2%|
#
# |State|ACT Participation Rate|
# |---|---|
# |Alabama|100%|
# |Arkansas|100%|
# |Colorado|100%|
# |Kentucky|100%|
# |Louisiana|100%|
# |Minnesota|100%|
# |Mississippi|100%|
# |Missouri|100%|
# |Montana|100%|
# |Nevada|100%|
# |North Carolina|100%|
# |Oklahoma|100%|
# |South Carolina|100%|
# |Tennessee|100%|
# |Utah|100%|
# |Wisconsin|100%|
# |Wyoming|100%|
# |...|...|
# |Maine|8%|
#
# ---

# %%
final.sort_values(by = 'sat_participation_18', ascending = True).head()
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 34  North Dakota                   2.0                         635
# 50       Wyoming                   3.0                         626
# 41  South Dakota                   3.0                         612
# 27      Nebraska                   3.0                         629
# 49     Wisconsin                   3.0                         642
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 34          621          1256                  98.0            19.0
# 50          604          1230                 100.0            19.4
# 41          603          1216                  80.0            20.7
# 27          625          1253                  84.0            20.9
# 49          649          1291                 100.0            19.7
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 34         20.4            20.5            20.6              20.3
# ...

# %%
high_sat_part_18 = final['sat_participation_18'] == 100.0
final[high_sat_part_18]
# Out:
#           state  sat_participation_17  sat_reading_and_writing_17  \
# 5      Colorado                  11.0                         606
# 6   Connecticut                 100.0                         530
# 7      Delaware                 100.0                         503
# 12        Idaho                  93.0                         513
# 22     Michigan                 100.0                         509
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 5           595          1201                 100.0            20.1
# 6           512          1041                  31.0            25.5
# 7           492           996                  18.0            24.1
# 12          493          1005                  38.0            21.9
# 22          495          1005                  29.0            24.1
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 5          20.3            21.2            20.9              20.8
# ...

# %%
final.sort_values(by = 'act_participation_18', ascending = True).head()
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 19          Maine                  95.0                         513
# 39   Rhode Island                  71.0                         539
# 29  New Hampshire                  96.0                         532
# 7        Delaware                 100.0                         503
# 38   Pennsylvania                  65.0                         540
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 19          499          1012                   8.0            24.2
# 39          524          1062                  21.0            24.0
# 29          520          1052                  18.0            25.4
# 7           492           996                  18.0            24.1
# 38          531          1071                  23.0            23.4
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 19         24.0            24.8            23.7              24.3
# ...

# %%
high_act_part_18 = final['act_participation_18'] == 100.0
final[high_act_part_18]
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 0          Alabama                   5.0                         593
# 3         Arkansas                   3.0                         614
# 17        Kentucky                   4.0                         631
# 18       Louisiana                   4.0                         611
# 24     Mississippi                   2.0                         634
# 25        Missouri                   3.0                         640
# 26         Montana                  10.0                         605
# 27        Nebraska                   3.0                         629
# 28          Nevada                  26.0                         563
# 33  North Carolina                  49.0                         546
# 35            Ohio                  12.0                         578
# 36        Oklahoma                   7.0                         530
# 40  South Carolina                  50.0                         543
# ...

# %% [markdown]
# ---
# ### Here we have the states with the highest and lowest participation rates for the SAT and ACT in 2018:
#
# |State|SAT Participation Rate|
# |---|---|
# |Colorado|100%|
# |Connecticut|100%|
# |Delaware|100%|
# |Idaho|100%|
# |Michigan|100%|
# |...|...|
# |North Dakota|2%|
#
# |State|ACT Participation Rate|
# |---|---|
# |Alabama|100%|
# |Arkansas|100%|
# |Kentucky|100%|
# |Louisiana|100%|
# |Minnesota|100%|
# |Mississippi|100%|
# |Missouri|100%|
# |Montana|100%|
# |Nevada|100%|
# |North Carolina|100%|
# |Ohio|100%|
# |Oklahoma|100%|
# |South Carolina|100%|
# |Tennessee|100%|
# |Utah|100%|
# |Wisconsin|100%|
# |Wyoming|100%|
# |...|...|
# |Maine|7%|
#
# ---

# %% [markdown]
# - Below are the lines of code for sorting the combined data by specific total/composite scores.

# %%
final.sort_values(by = 'sat_total_17', ascending = True).head(3)
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 8   District of Columbia                 100.0                         482
# 7               Delaware                 100.0                         503
# 12                 Idaho                  93.0                         513
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8           468           950                  32.0            24.4
# 7           492           996                  18.0            24.1
# 12          493          1005                  38.0            21.9
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 8          23.5            24.9            23.5              24.2
# 7          23.4            24.8            23.6              24.1
# 12         21.8            23.0            22.1              22.3
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# ...

# %%
final.sort_values(by = 'sat_total_17', ascending = False).head(3)
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 23  Minnesota                   3.0                         644          651
# 49  Wisconsin                   3.0                         642          649
# 15       Iowa                   2.0                         641          635
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 23          1295                 100.0            20.4         21.5
# 49          1291                 100.0            19.7         20.4
# 15          1275                  67.0            21.2         21.3
#
#     act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# 23            21.8            21.6              21.5                   4.0
# 49            20.6            20.9              20.5                   3.0
# 15            22.6            22.1              21.9                   3.0
#
#     sat_reading_and_writing_18  sat_math_18  sat_total_18  \
# ...

# %%
final.sort_values(by = 'act_composite_17', ascending = True).head(3)
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 28          Nevada                  26.0                         563
# 24     Mississippi                   2.0                         634
# 40  South Carolina                  50.0                         543
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 28          553          1116                 100.0            16.3
# 24          607          1242                 100.0            18.2
# 40          521          1064                 100.0            17.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 28         18.0            18.1            18.2              17.8
# 24         18.1            18.8            18.8              18.6
# 40         18.6            19.1            18.9              18.7
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 28                  23.0                         574          566
# ...

# %%
final.sort_values(by = 'act_composite_17', ascending = False).head(3)
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 29  New Hampshire                  96.0                         532
# 21  Massachusetts                  76.0                         555
# 6     Connecticut                 100.0                         530
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 29          520          1052                  18.0            25.4
# 21          551          1107                  29.0            25.4
# 6           512          1041                  31.0            25.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 29         25.1            26.0            24.9              25.5
# 21         25.3            25.9            24.7              25.4
# 6          24.6            25.6            24.6              25.2
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 29                  96.0                         535          528
# ...

# %% [markdown]
# ---
# ### Here we have the states with the highest and lowest total/composite scores for the SAT and ACT in 2017:
#
# |State|SAT Total Score|
# |---|---|
# |Minnesota|1295|
# |...|...|
# |District of Columbia|950|
#
# |State|ACT Composite Score|
# |---|---|
# |New Hampshire|25.5|
# |...|...|
# |Nevada|17.8|
#
# ---

# %%
final.sort_values(by = 'sat_total_18', ascending = True).head(3)
# Out:
#                    state  sat_participation_17  sat_reading_and_writing_17  \
# 8   District of Columbia                 100.0                         482
# 7               Delaware                 100.0                         503
# 48         West Virginia                  14.0                         558
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8           468           950                  32.0            24.4
# 7           492           996                  18.0            24.1
# 48          528          1086                  69.0            20.0
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 8          23.5            24.9            23.5              24.2
# 7          23.4            24.8            23.6              24.1
# 48         19.4            21.2            20.5              20.4
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# ...

# %%
final.sort_values(by = 'sat_total_18', ascending = False).head(3)
# Out:
#            state  sat_participation_17  sat_reading_and_writing_17  \
# 23     Minnesota                   3.0                         644
# 49     Wisconsin                   3.0                         642
# 34  North Dakota                   2.0                         635
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 23          651          1295                 100.0            20.4
# 49          649          1291                 100.0            19.7
# 34          621          1256                  98.0            19.0
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 23         21.5            21.8            21.6              21.5
# 49         20.4            20.6            20.9              20.5
# 34         20.4            20.5            20.6              20.3
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 23                   4.0                         643          655
# ...

# %%
final.sort_values(by = 'act_composite_18', ascending = True).head(3)
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 28          Nevada                  26.0                         563
# 40  South Carolina                  50.0                         543
# 24     Mississippi                   2.0                         634
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 28          553          1116                 100.0            16.3
# 40          521          1064                 100.0            17.5
# 24          607          1242                 100.0            18.2
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 28         18.0            18.1            18.2              17.8
# 40         18.6            19.1            18.9              18.7
# 24         18.1            18.8            18.8              18.6
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 28                  23.0                         574          566
# ...

# %%
final.sort_values(by = 'act_composite_18', ascending = False).head(3)
# Out:
#             state  sat_participation_17  sat_reading_and_writing_17  \
# 6     Connecticut                 100.0                         530
# 21  Massachusetts                  76.0                         555
# 29  New Hampshire                  96.0                         532
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 6           512          1041                  31.0            25.5
# 21          551          1107                  29.0            25.4
# 29          520          1052                  18.0            25.4
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 6          24.6            25.6            24.6              25.2
# 21         25.3            25.9            24.7              25.4
# 29         25.1            26.0            24.9              25.5
#
#     sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 6                  100.0                         535          519
# ...

# %% [markdown]
# ---
# ### Here we have the states with the highest and lowest total/composite scores for the SAT and ACT in 2018:
#
# |State|SAT Total Score|
# |---|---|
# |Minnesota|1298|
# |...|...|
# |District of Columbia|977|
#
# |State|ACT Composite Score|
# |---|---|
# |Connecticut|25.6|
# |...|...|
# |Nevada|17.7|
#
# ---

# %% [markdown]
# - Below are the lines of code to sort the combined data to determine states with 100% participation on a given test that may have a rate change year-to-year.

# %%
sat_2017 = final['sat_participation_17'] == 100.0
sat_2018 = final['sat_participation_18'] != 100.0

final[sat_2017 & sat_2018]
# Out:
#                   state  sat_participation_17  sat_reading_and_writing_17  \
# 8  District of Columbia                 100.0                         482
#
#    sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 8          468           950                  32.0            24.4
#
#    act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 8         23.5            24.9            23.5              24.2
#
#    sat_participation_18  sat_reading_and_writing_18  sat_math_18  \
# 8                  92.0                         497          480
#
#    sat_total_18  act_participation_18  act_composite_18
# 8           977                  32.0              23.6

# %%
sat_2017 = final['sat_participation_17'] != 100.0
sat_2018 = final['sat_participation_18'] == 100.0

final[sat_2017 & sat_2018]
# Out:
#        state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 5   Colorado                  11.0                         606          595
# 12     Idaho                  93.0                         513          493
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 5           1201                 100.0            20.1         20.3
# 12          1005                  38.0            21.9         21.8
#
#     act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# 5             21.2            20.9              20.8                 100.0
# 12            23.0            22.1              22.3                 100.0
#
#     sat_reading_and_writing_18  sat_math_18  sat_total_18  \
# 5                          519          506          1025
# 12                         508          493          1001
#
#     act_participation_18  act_composite_18
# 5                   30.0              23.9
# ...

# %%
act_2017 = final['act_participation_17'] == 100.0
act_2018 = final['act_participation_18'] != 100.0

final[act_2017 & act_2018]
# Out:
#         state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 5    Colorado                  11.0                         606          595
# 23  Minnesota                   3.0                         644          651
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 5           1201                 100.0            20.1         20.3
# 23          1295                 100.0            20.4         21.5
#
#     act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# 5             21.2            20.9              20.8                 100.0
# 23            21.8            21.6              21.5                   4.0
#
#     sat_reading_and_writing_18  sat_math_18  sat_total_18  \
# 5                          519          506          1025
# 23                         643          655          1298
#
#     act_participation_18  act_composite_18
# 5                   30.0              23.9
# ...

# %%
act_2017 = final['act_participation_17'] != 100.0
act_2018 = final['act_participation_18'] == 100.0

final[act_2017 & act_2018]
# Out:
#        state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 27  Nebraska                   3.0                         629          625
# 35      Ohio                  12.0                         578          570
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 27          1253                  84.0            20.9         20.9
# 35          1149                  75.0            21.2         21.6
#
#     act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# 27            21.9            21.5              21.4                   3.0
# 35            22.5            22.0              22.0                  18.0
#
#     sat_reading_and_writing_18  sat_math_18  sat_total_18  \
# 27                         629          623          1252
# 35                         552          547          1099
#
#     act_participation_18  act_composite_18
# 27                 100.0              20.1
# ...

# %% [markdown]
# ---
# ### 100% Participation Rate Year-to-Year Changes
#
# For the SAT:
#
# |State|2017|2018|
# |---|---|---|
# |District of Columbia|100%|92%|
# |Colorado|11%|100%|
# |Idaho|93%|100%|
#
# For the ACT:
#
# |State|2017|2018|
# |---|---|---|
# |Colorado|100%|30%|
# |Minnesota|100%|99%|
# |Nebraska|84%|100%|
# |Ohio|75%|100%|
#
# ---

# %% [markdown]
# - Below are the lines of code that help filter through the combined data to see if any states that had a participation rate greater than 50% on both the SAT and the ACT in 2017 or 2018.

# %%
act_17 = final['act_participation_17'] > 50.0
sat_17 = final['sat_participation_17'] > 50.0

final[act_17 & sat_17]
# Out:
#       state  sat_participation_17  sat_reading_and_writing_17  sat_math_17  \
# 9   Florida                  83.0                         520          497
# 10  Georgia                  61.0                         535          515
# 11   Hawaii                  55.0                         544          541
#
#     sat_total_17  act_participation_17  act_english_17  act_math_17  \
# 9           1017                  73.0            19.0         19.4
# 10          1050                  55.0            21.0         20.9
# 11          1085                  90.0            17.8         19.2
#
#     act_reading_17  act_science_17  act_composite_17  sat_participation_18  \
# 9             21.0            19.4              19.8                  56.0
# 10            22.0            21.3              21.4                  70.0
# 11            19.2            19.3              19.0                  56.0
#
#     sat_reading_and_writing_18  sat_math_18  sat_total_18  \
# ...

# %%
act_18 = final['act_participation_18'] > 50.0
sat_18 = final['sat_participation_18'] > 50.0

final[act_18 & sat_18]
# Out:
#              state  sat_participation_17  sat_reading_and_writing_17  \
# 9          Florida                  83.0                         520
# 10         Georgia                  61.0                         535
# 11          Hawaii                  55.0                         544
# 33  North Carolina                  49.0                         546
# 40  South Carolina                  50.0                         543
#
#     sat_math_17  sat_total_17  act_participation_17  act_english_17  \
# 9           497          1017                  73.0            19.0
# 10          515          1050                  55.0            21.0
# 11          541          1085                  90.0            17.8
# 33          535          1081                 100.0            17.8
# 40          521          1064                 100.0            17.5
#
#     act_math_17  act_reading_17  act_science_17  act_composite_17  \
# 9          19.4            21.0            19.4              19.8
# ...

# %% [markdown]
# ---
# ### Participation Rate > 50% on SAT/ACT in Either Year
#
# For 2017:
#
# |State|SAT Participation|ACT Participation|
# |---|---|---|
# |Florida|83%|73%|
# |Georgia|61%|55%|
# |Hawaii|55%|90%|
#
# For 2018:
#
# |State|SAT Participation|ACT Participation|
# |---|---|---|
# |Florida|56%|66%|
# |Georgia|70%|53%|
# |Hawaii|56%|89%|
# |North Carolina|52%|100%|
# |South Carolina|55%|100%|
#
# ---

# %% [markdown]
# ### Interesting Observations
# - District of Columbia has one of the highest SAT participation rates, but has the lowest total score in both 2017 and 2018.
#
# - Minnesota also has one of the lowest SAT participation rates, but has the highest total score  in both 2017 and 2018.
#
# - Maine also caught my attention upon further analysis when comparing ACT participation rates and ACT Composite Scores.
# ---

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize=(16, 9))

sns.heatmap(final.corr(),
            cmap = 'RdBu',
            vmin = -1,
            vmax = 1,
            annot = True)

plt.title('Heatmap Correlation', fontsize = 30)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15);

# %% [markdown]
# _Chart 1: Heatmap Correlation_
#
# Finds the correlation between one column's value and another column's value from the master combined data set. For example the correlation between "sat_participation_17" on the x-axis and "act_composite_18" on the y-axis is 0.64, which says there is a somewhat strong relationship between the two variables.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (16,9)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title(list_of_titles[i], fontsize = 20)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize = 16)
        # Set titles, labels, etc here for each subplot
    plt.tight_layout()

# %% [markdown]
# ### Plot and Interpret Histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(final,
                   ['sat_participation_17', 'sat_participation_18'],
                   ["SAT Participation Rates 2017", "SAT Participation Rates 2018"],
                   ["Participation Rate (%)", "Participation Rate (%)"])

# %% [markdown]
# _Chart 2: SAT Participation Rates - Histograms_
#
# Gives a side by side distribution of the 2017 SAT Participation Rates  and 2018 SAT Participation Rates for all 50 states and DC. Many states (almost half) had signficantly low participation (about 10% to 15%). Generally, the distribution doesn't differ drastically entailing that the participation didn't differ from year to year.

# %%
subplot_histograms(final,
                   ['act_participation_17', 'act_participation_18'],
                   ["ACT Participation Rates 2017", "ACT Participation Rates 2018"],
                   ["Participation Rate (%)", "Participation Rate (%)"])

# %% [markdown]
# _Chart 3: ACT Participation Rates - Histograms_
#
# Gives a side by side distribution of the 2017 ACT Participation Rates  and 2018 ACT Participation Rates for all 50 states and DC. Many states (about 40%) had signficantly high participation (about 90% to 100%).Generally, the distribution doesn't differ drastically; there is a slight increase in lower participation rates.

# %%
subplot_histograms(final,
                   ['sat_math_17', 'sat_math_18'],
                   ["SAT Math Scores 2017", "SAT Math Scores 2018"],
                   ["Math Scores", "Math Scores"])

# %% [markdown]
# _Chart 4: SAT Math Scores - Histograms_
#
# Gives a side by side distribution of the 2017 SAT Math Scores and 2018 Math Scores for all 50 states and DC. Generally, the distribution doesn't differ drastically and is somewhat normal where we can see that the highest bar indicates the average national score, which is approximately 530.

# %%
subplot_histograms(final,
                   ['sat_math_17', 'act_math_17'],
                   ["SAT Math Scores 2017", "ACT Math Scores 2017"],
                   ["Math Scores", "Math Scores"])

# %% [markdown]
# _Chart 5: SAT v ACT 2017 Math Scores - Histograms_
#
# Gives a side by side distribution of the 2017 SAT Math Scores and 2017 ACT Math Scores for all 50 states and DC. Looking at the SAT Math Score distribution, it seems somewhat normal where the national average is about 530. Looking at the ACT Math score distribution it is more widespread where the national average isn't easily distinguishable, but shows that performance ranges well between 18 and 26.

# %%
subplot_histograms(final,
                   ['sat_reading_and_writing_17', 'sat_reading_and_writing_18'],
                   ["SAT Verbal Scores 2017", "SAT Verbal Scores 2018"],
                   ["Verbal Scores", "Verbal Scores"])

# %% [markdown]
# _Chart 6: SAT Verbal Scores - Histograms_
#
# Gives a side by side distribution of the 2017 SAT Verbal Scores and 2018 Verbal Scores for all 50 states and DC. Generally, the distribution doesn't differ drastically between the years, but there is a large gap between 570 to 630 as not many states score in this range.

# %%
subplot_histograms(final,
                   ['sat_reading_and_writing_17', 'act_reading_17', 'act_english_17'],
                   ["SAT Verbal Scores 2017", "ACT Reading Scores 2017", "ACT English Scores 2017"],
                   ["SAT Verbal Scores", "ACT Reading Scores", "ACT English"])

# %% [markdown]
# _Chart 7: SAT v ACT 2017 Verbal Scores - Histograms_
#
# Gives the distributions of the 2017 SAT Verbal Scores and 2017 ACT Reading and English Scores for all 50 states and DC. Looking at the ACT Reading and English Scores distributions, they are generally the same, but there is a slightly better performance on the English section than the Reading section. In relation to the SAT Verbal Scores distribution there isn't a significant dip between the national average and the top scorers.

# %% [markdown]
# ### Plot and Interpret Scatter Plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_math_17'], 
           final['act_math_17'], 
           color = "Red")

plt.title("SAT vs ACT Math Scores for 2017", fontsize = 20)
plt.xlabel("SAT Math Scores", fontsize = 10, labelpad = 10)
plt.ylabel("ACT Math Scores", fontsize = 10, labelpad = 10);

# %% [markdown]
# _Chart 8: SAT v ACT 2017 Math Scores - Scatterplot_
#
# Gives the correlation between the 2017 SAT Math Scores and the 2017 ACT Math Scores and how strong of a relationship they have. The points are quite scattered entailing that as the SAT Math Score goes up, the ACT Math Score doesn't increase in proportion or in respect to it.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_reading_and_writing_17'], 
           final['act_reading_17'],
           color = "Red")

plt.title("SAT vs ACT Verbal/Reading Scores for 2017", fontsize = 20)
plt.xlabel("SAT Reading and Writing Scores", fontsize = 10, labelpad = 10)
plt.ylabel("ACT Reading Scores", fontsize = 10, labelpad = 10);

# %% [markdown]
# _Chart 9: SAT Verbal v ACT Reading 2017 Scores - Scatterplot_
#
# Gives the correlation between the 2017 SAT Verbal Scores and the 2017 ACT Reading Scores and how strong of a relationship they have. The points are quite scattered entailing that as the SAT Verbal Score goes up, the ACT Reading Score doesn't increase in proportion or in respect to it.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_reading_and_writing_17'], 
           final['act_english_17'], 
           color = "Red")

plt.title("SAT vs ACT Verbal/English Scores for 2017", fontsize = 20)
plt.xlabel("SAT Reading and Writing Scores", fontsize = 10, labelpad = 10)
plt.ylabel("ACT English Scores", fontsize = 10, labelpad = 10);

# %% [markdown]
# _Chart 10: SAT Verbal v ACT English 2017 Scores - Scatterplot_
#
# Gives the correlation between the 2017 SAT Verbal Scores and the 2017 ACT English Scores and how strong of a relationship they have. The points are quite scattered entailing that as the SAT Verbal Score goes up, the ACT English Score doesn't increase in proportion or in respect to it.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_total_17'], 
           final['act_composite_17'], 
           color = "Red")

plt.title("SAT vs ACT Total/Composite for 2017", fontsize = 20)
plt.xlabel("SAT Total Scores", fontsize = 15, labelpad = 10)
plt.ylabel("ACT Composite Scores", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 11: SAT Total v ACT Composite 2017 Scores - Scatterplot_
#
# Gives the correlation between the 2017 SAT Total Scores and the 2017 ACT Composite Scores and how strong of a relationship they have. The points are quite scattered entailing that as the SAT Total Score goes up, the ACT Composite Score doesn't increase in proportion or in respect to it.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_total_17'], 
           final['sat_total_18'], 
           color = "Red")

plt.title("SAT Total Scores- 2017 v 2018", fontsize = 20)
plt.xlabel("SAT Total Scores 2017", fontsize = 15, labelpad = 10)
plt.ylabel("SAT Total Scores 2018", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 12: SAT Total Scores 2017 v 2018 - Scatterplot_
#
# Gives the correlation between the 2017 SAT Total Scores and the 2018 SAT Total Scores and how strong of a relationship they have. The points essentially form a increasing straight line entailing that as the 2017 SAT Total Score goes up, the 2018 SAT Total Score also increases in proportion or in respect to it.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['act_composite_17'], 
           final['act_composite_18'], 
           color = "Red")

plt.title("ACT Composite Scores - 2017 v 2018", fontsize = 20)
plt.xlabel("ACT Composite Scores 2017", fontsize = 15, labelpad = 10)
plt.ylabel("ACT Composite Scores 2018", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 13: ACT Composite Scores 2017 v 2018 - Scatterplot_
#
# Gives the correlation between the 2017 ACT Composite Scores and the 2018 ACT Composite Scores and how strong of a relationship they have. The points essentially form a increasing straight line entailing that as the 2017 ACT Composite Score goes up, the 2018 ACT Composite Score also increases in proportion or in respect to it.

# %% [markdown]
# ### Plot and Interpret Boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
sns.boxplot(data = final[['sat_participation_17', 'sat_participation_18']], orient = 'horizontal')
plt.title('SAT Participation 2017 v 2018', fontsize= 15)
plt.xlabel('Participation Rates (%)', fontsize = 10);

# %% [markdown]
# _Chart 14: SAT Participation Rates 2017 - Boxplot_
#
# Shows us the range of the participation rates along with the interquartile range (the colored section) where most of the data falls. The median participation rate is about 40% with lower quarter entailing that many states had between 5% to 40% participation for 2017. The median participation rate is about 50% with lower quarter entailing that many states had between 5% to 50% participation for 2018.

# %%
sns.boxplot(data = final[['act_participation_17', 'act_participation_18']], orient = 'horizontal')
plt.title('ACT Participation 2017', fontsize= 15)
plt.xlabel('Participation Rates (%)', fontsize = 10);

# %% [markdown]
# _Chart 15: ACT Participation Rates 2017 v 2018 - Boxplot_
#
# Shows us the range of the participation rates along with the interquartile range (the colored section) where most of the data falls, which includes the maximum. The median participation rate is about 70% with the slightly larger lower quarter entailing that more states had between 30% to 70% participation for 2017. The median participation rate is about 65% with the slightly larger lower quarter entailing that more states had between 30% to 65% participation for 2018.

# %%
sns.boxplot(data = final[['sat_total_17', 'sat_total_18']], orient = 'horizontal')
plt.title('SAT Total Scores 2017', fontsize= 15)
plt.xlabel('Total Scores', fontsize = 10);

# %% [markdown]
# _Chart 16: SAT Total Scores 2017 v 2018 - Boxplot_
#
# Shows us the range of the total scores along with the interquartile range (the colored section) where most of the data falls. The median total score is about 1110 with the larger upper quarter entailing that more states scored between 1110 to 1220 for 2017. The median total score is about 1100 with the larger upper quarter entailing that more states scored between 1100 to 1210 for 2018.

# %%
sns.boxplot(data = final[['act_composite_17', 'act_composite_18']], orient = 'horizontal')
plt.title('ACT Composite Scores 2017', fontsize= 15)
plt.xlabel('Composite Scores', fontsize = 10);

# %% [markdown]
# _Chart 17: ACT Composite Scores 2017 - Boxplot_
#
# Shows us the range of the total scores along with the interquartile range (the colored section) where most of the data falls. The median total score is about 21.3 with the larger upper quarter entailing that more states scored between 21.3 to 23.4 for 2017. The median total score is about 21.3 with the larger upper quarter entailing that more states scored between 21.3 to 23.4 for 2018. Notice how there isn't much of a difference from 2017.

# %% [markdown]
# ---
# Notable Comments:
#
# - SAT and ACT participation rates are practically on opposite sides of the spectrum, but yield a relatively equal total/composite score.
#
# ---

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['act_participation_17'], 
           final['act_composite_17'], 
           color = 'Purple')

plt.title("2017 ACT Participation vs Composite", fontsize = 20)
plt.xlabel("ACT Participation Rates (%)", fontsize = 15, labelpad = 10)
plt.ylabel("ACT Composite Scores", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 18: ACT Participation Rates v ACT Composite Scores 2017 - Scatterplot_
#
# Gives the correlation between the 2017 ACT Composite Scores and the 2017 ACT Participation Rates and how strong of a relationship they have. The points partly form a decreasing straight line entailing that as the 2017 ACT Participation Rate goes up, the 2017 ACT Composite Score decreases in proportion or in respect to it partly. According the the heatmap from Chart 1, the actual correlation is -0.86, which is a relatively strong correlation.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['act_participation_18'], 
           final['act_composite_18'],
           color = 'Purple')

plt.title("2018 ACT Participation vs Composite", fontsize = 20)
plt.xlabel("ACT Participation Rates (%)", fontsize = 15, labelpad = 10)
plt.ylabel("ACT Composite Scores", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 19: ACT Participation Rates v ACT Composite Scores 2018 - Scatterplot_
#
# Gives the correlation between the 2018 ACT Composite Scores and the 2018 ACT Participation Rates and how strong of a relationship they have. The points partly form a decreasing straight line entailing that as the 2018 ACT Participation Rate goes up, the 2018 ACT Composite Score decreases in proportion or in respect to it partly. According the the heatmap from Chart 1, the actual correlation is -0.86, which is a relatively strong correlation.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_participation_17'], 
           final['sat_total_17'], 
           color = 'Purple')

plt.title("2017 SAT Participation vs Total Score", fontsize = 20)
plt.xlabel("SAT Participation Rates (%)", fontsize = 15, labelpad = 10)
plt.ylabel("SAT Total Scores", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 20: SAT Participation Rates v SAT Total Scores 2017 - Scatterplot_
#
# Gives the correlation between the 2017 SAT Total Scores and the 2017 SAT Participation Rates and how strong of a relationship they have. The points partly form a decreasing straight line entailing that as the 2017 SAT Participation Rate goes up, the 2017 SAT Total Score decreases in proportion or in respect to it partly. According the the heatmap from Chart 1, the actual correlation is -0.87, which is a relatively strong correlation.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(final['sat_participation_18'], 
           final['sat_total_18'],
           color = 'Purple')

plt.title("2018 SAT Participation vs Total Score", fontsize = 20)
plt.xlabel("SAT Participation Rates (%)", fontsize = 15, labelpad = 10)
plt.ylabel("SAT Total Scores", fontsize = 15, labelpad = 10);

# %% [markdown]
# _Chart 21: SAT Participation Rates v SAT Total Scores 2018 - Scatterplot_
#
# Gives the correlation between the 2018 SAT Total Scores and the 2018 SAT Participation Rates and how strong of a relationship they have. The points partly form a decreasing straight line entailing that as the 2018 SAT Participation Rate goes up, the 2018 SAT Total Score decreases in proportion or in respect to it partly. According the the heatmap from Chart 1, the actual correlation is -0.79, which is a relatively strong correlation.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Research Findings:
# After further chart comparisons, what I noticed intially peaked my interest even more so I decided to research anything that may explain the following observations:
#
# - District of Columbia has one of the highest SAT participation rates, but has the lowest total score in both 2017 and 2018.
#
# - Minnesota also has one of the lowest SAT participation rates, but has the highest total score in both 2017 and 2018.
#
# - Maine also caught my attention upon further analysis when comparing ACT participation rates and ACT Composite Scores.
#
# Primarily, I pulled up the statistics for each state's exam reports to get a detailed analytical breakdown that would include relevant factors of comparison across the nation. Upon reading through the reports, I noticed how demographics across the states of interest were quite different. There is a well-known stigma regarding academic performance based on a person's ethnic background.
#
# According to a study by California Healthy Kids Survey WestEd, Whites and Asians consistently had the most positive results across all indicators regarding school performance, engagement, safety, and supports. I isolated my analysis on school performance and engagement where the categories were broken down into grades, truancy, and school connectedness. The study also involved a comparison between 7th Graders vs 9th/11th Graders. Based on my focus, Whites and Asians had the two most positive results across both grade comparisons, while African Americans (and Latinos) had the most negative results across both grade comparisons amongst all demographics.
#
# **Grades mostly Bs and above:**
#
# - Asians: 82% in 7th Grade to 75% in 9th/11th Grades
# - Whites: 74% in 7th Grade to 65% in 9th/11th Grades
# - African Americans: 56% in 7th Grade to 49% in 9th/11th Grades
# - Latinos: 54% in 7th Grade to 44% in 9th/11th Grades
#
# **Truant only two times or less:**
#
# - Asians: 95% in 7th Grade to 82% in 9th/11th Grades
# - Whites: 93% in 7th Grade to 76% in 9th/11th Grades
# - African Americans: 88% in 7th Grade to 72% in 9th/11th Grades
# - Latinos: 89% in 7th Grade to 71% in 9th/11th Grades
#
# **School Connectedness - High:**
#
# - Asians: 51% in 7th Grade to 42% in 9th/11th Grades
# - Whites: 53% in 7th Grade to 47% in 9th/11th Grades
# - African Americans: 34% in 7th Grade to 31% in 9th/11th Grades
# - Latinos: 42% in 7th Grade to 37% in 9th/11th Grades
#
# College Readiness (ACT measured benchmarks), despite what State, proved to be significantly lower for African Americans and Latinos while Whites and Asians ranked relatively higher than all other races.
#
# ![college_readiness](../images/college_readiness.png)
# ![benchmark](../images/benchmarks.png)
#
# ### District of Columbia
#
# - High SAT Participation Rate and Low SAT Total Score in  2017 and 2018
#
# As of the 2017 Census Bureau data, the population had the following ethnic composition:
#
# |Race|Percentage|
# |---|---|
# |Black/African American|47.75%|
# |White|40.67%|
# |Asian| 3.8%|
# |Native American|0.26%|
# |Other|7.51%|
#
# Out of all the test takers for the 2017 SAT, 56% were Black/African American and 16% were Latino (which comprise the highest two), while 14% were White and 2% were Asian.
#
# - Total High School Graduates: 5,305
# - Total Test Takers: 4,801
#     - Black/African American: 2,705
#     - Latino: 752
#     - White: 669
#     - Asian: 99
#
# In the following 2018 SAT, the ethnic breakdown didn't vary by much.
#
# - Total High School Graduates: 5,397
# - Total Test Takers: 4,985
#     - Black/Afican American: 2,295 (46%)
#     - Latino: 769 (15%)
#     - White: 858 (17%)
#     - Asian: 121 (2%)
#
# ### Minnesota
#
# - Low SAT Participation Rate and High SAT Total Score in  2017 and 2018
#
# As of the 2017 Census Bureau data, the population had the following ethnic composition:
#
# |Race|Percentage|
# |---|---|
# |White|83.75%|
# |Black/African American| 5.95%|
# |Asian| 4.66%|
# |Native American|1.05%|
# |Other|4.59%|
#
# Out of all the test takers for the 2017 SAT, 63% were White and 21% were Asian (which comprise the highest two), while 5% were Black/African American and 5% were Latino.
#
# - Total High School Graduates: 60,915
# - Total Test Takers: 2,061
#     - White: 1,293
#     - Asian: 426
#     - Black/Afican American: 102
#     - Latino: 98
#
# In the following 2018 SAT, the ethnic breakdown didn't vary by much.
#
# - Total High School Graduates: 61,766
# - Total Test Takers: 2,464
#     - White: 1,520 (62%)
#     - Asian: 513 (21%)
#     - Black/Afican American: 108 (4%)
#     - Latino: 131 (5%)
#
# ### Maine
#
# - Low ACT Participation and High ACT Composite Score in 2017 and 2018
#
# As of the 2017 Census Bureau data, the population had the following ethnic composition:
#
# |Race|Percentage|
# |---|---|
# |White|94.64%|
# |Black/African American| 1.27%|
# |Asian| 1.11%|
# |Native American|0.62%|
# |Other|2.35%|
#
# Out of all the test takers for the 2017 ACT, 76% were White and 8% were Asian (which comprise the highest two), while 2% were Black/African American and 3% were Latino.
#
# - Total High School Graduates: 15,050
# - Total Test Takers: 1,204
#     - White: 915
#     - Asian: 96
#     - Black/Afican American: 24
#     - Latino: 36
#
# In the following 2018 ACT, the ethnic breakdown didn't vary by much.
#
# - Total High School Graduates: 14,900
# - Total Test Takers: 1,043
#     - White: 824 (79%)
#     - Asian: 73 (7%)
#     - Black/Afican American: 21 (2%)
#     - Latino: 20 (2%)
#
# Maine proved to strive above other states that had 100% ACT Participation Rates. Despite having the lowest participation, it yielded a composite score well above the national average of 21.0 at 23.4 in 2017 and 24.0 in 2018. On the other hand, of all the states that had 100% participation, none yielded a composite score above the national average.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# After comparing multiple variables from the datasets about the 2017 and 2018 SAT and ACT, we can conclude that participation rates don't truly affect the overall score. While SAT participation rates are generally on the lower side versus ACT participation rates which were generally on the upper side, looking at the individual distributions of the overall scores, the SAT and ACT fell in the middle.
#
# Upon more in-depth research as to what factors may contribute to these results, we came across racial demographics. From what we noticed through exploring the data, the following were noted:
#
# - District of Columbia has one of the highest SAT participation rates, but has the lowest total score in both 2017 and 2018.
#
# - Minnesota has one of the lowest SAT participation rates, but has the highest total score in both 2017 and 2018.
#
# - Maine has the lowest ACT participation rates and the highest ACT Composite Scores in both 2017 and 2018 - well above the national average.
#
# Based on racial/ethinic breakdowns, it can be seen that test takers from Minnesota and Maine were mostly White (about 60% to 70% across 2017 and 2018) while a fraction of those test takers were African Americans and Latinos (about 5% to 10% across 2017 and 2018). Furthermore, looking at the racial breakdown of test takers in the District of Columbia, most were African American (about 60% to 70% across 2017 and 2018) while a fraction of total test takers were White (about 15% across 2017 and 2018).
#
# It's difficult to say why there is such a large gap between academic performance and race as many factors can contribute such as finances for SAT/ACT prep classes or the accessibility to SAT/ACT resources (at school and outside of school). The data also doesn't explain as to why the ACT participation is much higher than the SAT. However, based on research on the exams, the ACT does seem more appealing to STEM individuals as a calculator is allowed on all math questions and there is less reading comprehension involved.
#
# In order to promote SAT participation, some ways to entice potential test takers are:
#
# - Hosting the exam on a school day as this can prevent any part-time job conflicts and also allow students to maintain that 5 day school week instead of having a "6 day school week."
#
# - Consulting with Boards of Education in regards to providing classes or electives that are centered around SAT prep in school.

# %% [markdown]
# ## Source Documentations
#
# 1. [2017 SAT for DC](https://reports.collegeboard.org/pdf/2017-district-columbia-sat-suite-assessments-annual-report.pdf)
#
# 2. [2018 SAT for DC](https://reports.collegeboard.org/pdf/2018-district-columbia-sat-suite-assessments-annual-report.pdf)
#
# 3. [2017 SAT for Minnesota](https://reports.collegeboard.org/pdf/2017-minnesota-sat-suite-assessments-annual-report.pdf)
#
# 4. [2018 SAT for Minnesota](https://reports.collegeboard.org/pdf/2018-minnesota-sat-suite-assessments-annual-report.pdf)
#
# 5. [2017 ACT for Maine](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/Maine-CCCR-2017-Final.pdf)
#
# 6. [2018 ACT for Maine](https://www.act.org/content/dam/act/unsecured/documents/cccr2018/Maine-CCCR-2018.pdf)
#
# 7. [DC Demographics](http://worldpopulationreview.com/states/district-of-columbia-population/)
#
# 8. [Minnesota Demographics](http://worldpopulationreview.com/states/minnesota-population/)
#
# 9. [Maine Demographics](http://worldpopulationreview.com/states/maine-population/)
#
# 10. [California Healthy Kids Survey WestEd](https://data.calschls.org/resources/FACTSHEET-9.pdf)
#
# 11. [ACT College Readiness](https://www.act.org/content/dam/act/unsecured/documents/National-CCCR-2019.pdf)
#
# 12. [How Students View Learning](http://www.sedl.org/change/issues/issues53.html)
#
# 13. [What Teens Want From School](https://fordhaminstitute.org/national/commentary/what-teens-want-their-schools)
#
# 14. [SAT vs ACT](https://www.usnews.com/education/best-colleges/articles/act-vs-sat-how-to-decide-which-test-to-take)
